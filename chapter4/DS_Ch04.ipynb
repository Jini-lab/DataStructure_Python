# %%
for i in {1, 2, 3, 4}:
   print(i, end =' ')
# Out:
# 1 2 3 4

# %%
t=(1,3,5,7)
print(t)
# Out:
# (1, 3, 5, 7)

# %%
for x in t:
   print(x)
# Out:
# 1
# 3
# 5
# 7

# %%
a=[1,3,5,7]
print(a)
# Out:
# [1, 3, 5, 7]

# %%
for i in {21, 32, 3, 10}:
   print(i, end =' ')
# Out:
# 32 10 3 21

# %%
class Sample:
  def __init__(self):
    self.counter = 0

  def numEven(self, n):
    for k in range(n):
      if k % 2 == 0:
        self.counter +=1
    return self.counter

# %%
s = Sample()
print(s.numEven(15))
# Out:
# 8

# %%
class Sample:
  def __init__(self):
    self.counter = 0

  def numEven(self, n):
    for k in range(n):
      if k % 2 == 0:
        self.counter +=1
    return self.counter

s = Sample()
print(s.numEven(15))
# Out:
# 8

# %%
class Sample:
  counter2 = 0
  def __init__(self):
    self.counter = 0

  def numEven(self, n):
    for k in range(n):
      if k % 2 == 0:
        self.counter +=1
        Sample.counter2 +=1

# %%
s1 = Sample()
s2 = Sample()
s1.numEven(15)
s2.numEven(15)
print(s1.counter, s1.counter2)
# Out:
# 8 16

# %%
class Heap:
  def __init__(self):
# Out:
#   File "<ipython-input-10-631263eef8d7>", line 2
#     def __init__(self):
#                        ^
# SyntaxError: incomplete input

# %%
class Heap:
  counter = 0
  def __init__():
    Heap.counter = 0

# %%
class Test:
  def __init__(self):
    self.counter = 0

  counter = 0
  def count(self):
      self.counter +=1
      Heap.counter +=1

      print("(self.counter, Heap.counter) = (", self.counter, ",", Heap.counter,")")

# %%
def start():
  h1 = Test()
  h2 = Test()
  h1.count()
  h2.count()
  h2.count()

# %%
if __name__ == "__main__":
   start()
# Out:
# (self.counter, Heap.counter) = ( 1 , 1 )
# (self.counter, Heap.counter) = ( 1 , 2 )
# (self.counter, Heap.counter) = ( 2 , 3 )
